# %%
import pandas as pd
from datetime import datetime
import json

# %%
with open("clients.json",'r') as f:
    json_string = f.read()
    clients=json.loads(json_string)

print(clients["8743"])
# Out:
# {'2023-01-29T00:00:00-08:00': {'ATTRIBUTED': 175, 'UNATTRIBUTED': 15679, 'CR': 1.103822379210294, 'records': {'advocate_stats_email': {'source': 'advocate_stats_email', 'source_type': 'zone', 'ATTRIBUTED': True, 'UNATTRIBUTED': False, 'customers': 6}, 'advocate_earned_reward_email': {'source': 'advocate_earned_reward_email', 'source_type': 'zone', 'ATTRIBUTED': True, 'UNATTRIBUTED': False, 'customers': 3}, 'mail_after_purchase_email': {'source': 'mail_after_purchase_email', 'source_type': 'zone', 'ATTRIBUTED': True, 'UNATTRIBUTED': False, 'customers': 7}, 'global_footer': {'source': 'global_footer', 'source_type': 'link', 'ATTRIBUTED': True, 'UNATTRIBUTED': False, 'customers': 68}, 'global_header': {'source': 'global_header', 'source_type': 'zone', 'ATTRIBUTED': True, 'UNATTRIBUTED': False, 'customers': 28}, 'mow': {'source': 'mow', 'source_type': 'link', 'ATTRIBUTED': True, 'UNATTRIBUTED': False, 'customers': 3}, 'organic': {'source': 'organic', 'source_type': 'link', 'ATTRIBUTED': 
# ...
